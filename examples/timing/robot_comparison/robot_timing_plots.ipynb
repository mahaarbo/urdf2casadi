# %%
# %store -r kuka_timeit_g_rbdl
# %store -r kuka_timeit_C_rbdl
# %store -r kuka_timeit_id_rbdl
# %store -r kuka_timeit_M_rbdl
# %store -r kuka_timeit_fd_rbdl

# %%
# %store -r kuka_timeit_g_kdl
# %store -r kuka_timeit_C_kdl
# %store -r kuka_timeit_M_kdl

# %%
# %store -r kuka_timeit_g_pb
# %store -r kuka_timeit_C_pb
# %store -r kuka_timeit_id_pb
# %store -r kuka_timeit_M_pb

# %%
# %store -r kuka_timeit_g_u2c
# %store -r kuka_timeit_C_u2c
# %store -r kuka_timeit_id_u2c
# %store -r kuka_timeit_M_u2c
# %store -r kuka_timeit_fd_crba_u2c
# %store -r kuka_timeit_fd_aba_u2c

# %%
# %store -r snake_timeit_g_rbdl
# %store -r snake_timeit_C_rbdl
# %store -r snake_timeit_id_rbdl
# %store -r snake_timeit_M_rbdl
# %store -r snake_timeit_fd_rbdl

# %store -r snake_timeit_g_kdl
# %store -r snake_timeit_C_kdl
# %store -r snake_timeit_M_kdl

# %store -r snake_timeit_g_pb
# %store -r snake_timeit_C_pb
# %store -r snake_timeit_id_pb
# %store -r snake_timeit_M_pb

# %store -r snake_timeit_g_u2c
# %store -r snake_timeit_C_u2c
# %store -r snake_timeit_id_u2c
# %store -r snake_timeit_M_u2c
# %store -r snake_timeit_fd_crba_u2c
# %store -r snake_timeit_fd_aba_u2c

# %%
# %store -r pendel_timeit_g_rbdl
# %store -r pendel_timeit_C_rbdl
# %store -r pendel_timeit_id_rbdl
# %store -r pendel_timeit_M_rbdl
# %store -r pendel_timeit_fd_rbdl

# %store -r pendel_timeit_g_kdl
# %store -r pendel_timeit_C_kdl
# %store -r pendel_timeit_M_kdl

# %store -r pendel_timeit_g_pb
# %store -r pendel_timeit_C_pb
# %store -r pendel_timeit_id_pb
# %store -r pendel_timeit_M_pb

# %store -r pendel_timeit_g_u2c
# %store -r pendel_timeit_C_u2c
# %store -r pendel_timeit_id_u2c
# %store -r pendel_timeit_M_u2c
# %store -r pendel_timeit_fd_crba_u2c
# %store -r pendel_timeit_fd_aba_u2c

# %%
scale = 1000000
u2c_snake_C = median(snake_timeit_C_u2c)*scale
pb_snake_C = median(snake_timeit_C_pb)*scale
rbdl_snake_C = median(snake_timeit_C_rbdl)*scale
kdl_snake_C = median(snake_timeit_C_kdl)*scale

pb_snake_id = median(snake_timeit_id_pb)*scale
rbdl_snake_id = median(snake_timeit_id_rbdl)*scale
u2c_snake_id = median(snake_timeit_id_u2c)*scale

u2c_snake_g = median(snake_timeit_g_u2c)*scale
pb_snake_g = median(snake_timeit_g_pb)*scale
rbdl_snake_g = median(snake_timeit_g_rbdl)*scale
kdl_snake_g = median(snake_timeit_g_kdl)*scale

u2c_snake_M = median(snake_timeit_M_u2c)*scale
pb_snake_M = median(snake_timeit_M_pb)*scale
rbdl_snake_M = median(snake_timeit_M_rbdl)*scale
kdl_snake_M = median(snake_timeit_M_kdl)*scale

#u2c_snake_M = median(timeit_M_u2c)
#pb_snake_M = median(timeit_M_pb)
u2c_snake_fd = median(snake_timeit_fd_aba_u2c)*scale
rbdl_snake_fd = median(snake_timeit_fd_rbdl)*scale

# %%
u2c_pendel_C = median(pendel_timeit_C_u2c)*scale
pb_pendel_C = median(pendel_timeit_C_pb)*scale
rbdl_pendel_C = median(pendel_timeit_C_rbdl)*scale
kdl_pendel_C = median(pendel_timeit_C_kdl)*scale

pb_pendel_id = median(pendel_timeit_id_pb)*scale
rbdl_pendel_id = median(pendel_timeit_id_rbdl)*scale
u2c_pendel_id = median(pendel_timeit_id_u2c)*scale

u2c_pendel_g = median(pendel_timeit_g_u2c)*scale
pb_pendel_g = median(pendel_timeit_g_pb)*scale
rbdl_pendel_g = median(pendel_timeit_g_rbdl)*scale
kdl_pendel_g = median(pendel_timeit_g_kdl)*scale

u2c_pendel_M = median(pendel_timeit_M_u2c)*scale
pb_pendel_M = median(pendel_timeit_M_pb)*scale
rbdl_pendel_M = median(pendel_timeit_M_rbdl)*scale
kdl_pendel_M = median(pendel_timeit_M_kdl)*scale

#u2c_pendel_M = median(timeit_M_u2c)
#pb_pendel_M = median(timeit_M_pb)
u2c_pendel_fd = median(pendel_timeit_fd_aba_u2c)*scale
rbdl_pendel_fd = median(pendel_timeit_fd_rbdl)*scale

# %%
def median(lst):
    n = len(lst)
    if n < 1:
            return None
    if n % 2 == 1:
            return sorted(lst)[n//2]
    else:
            return sum(sorted(lst)[n//2-1:n//2+1])/2.0
        
def average(lst): 
    return sum(lst) / len(lst)

# %%
print median(timeit_C_u2c)
print median(timeit_C_kdl)
# Out:
# 2.90870666504e-05
# 1.90734863281e-05

# %%
u2c_kuka_C = median(kuka_timeit_C_u2c)*scale
pb_kuka_C = median(kuka_timeit_C_pb)*scale
rbdl_kuka_C = median(kuka_timeit_C_rbdl)*scale
kdl_kuka_C = median(kuka_timeit_C_kdl)*scale

pb_kuka_id = median(kuka_timeit_id_pb)*scale
rbdl_kuka_id = median(kuka_timeit_id_rbdl)*scale
u2c_kuka_id = median(kuka_timeit_id_u2c)*scale

u2c_kuka_g = median(kuka_timeit_g_u2c)*scale
pb_kuka_g = median(kuka_timeit_g_pb)*scale
rbdl_kuka_g = median(kuka_timeit_g_rbdl)*scale
kdl_kuka_g = median(kuka_timeit_g_kdl)*scale

u2c_kuka_M = median(kuka_timeit_M_u2c)*scale
pb_kuka_M = median(kuka_timeit_M_pb)*scale
rbdl_kuka_M = median(kuka_timeit_M_rbdl)*scale
kdl_kuka_M = median(kuka_timeit_M_kdl)*scale

#u2c_kuka_M = median(timeit_M_u2c)
#pb_kuka_M = median(timeit_M_pb)
u2c_kuka_fd = median(kuka_timeit_fd_aba_u2c)*scale
rbdl_kuka_fd = median(kuka_timeit_fd_rbdl)*scale

# %%
from bokeh.core.properties import value
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge
from bokeh.models import ColumnDataSource, ranges, LabelSet

output_file("dodged_bars.html")

fruits = ['G', 'C', 'ID', 'M', 'FD']
years = ['pybullet', 'RBDL', 'u2c']

data = {'fruits' : fruits,
        'pybullet'   : [pb_kuka_g, pb_kuka_C, pb_kuka_id, pb_kuka_M, 0],
        'RBDL'   : [rbdl_kuka_g, rbdl_kuka_C, rbdl_kuka_id, rbdl_kuka_M, rbdl_kuka_fd],
        'u2c'   : [u2c_kuka_g, u2c_kuka_C, u2c_kuka_id, u2c_kuka_M, u2c_kuka_fd],
        'KDL'   : [kdl_kuka_g, kdl_kuka_C, 0, kdl_kuka_M, 0]}

#data = {'fruits' : fruits,
#        'pybullet'   : [0.0002, 0.0001, 0.0004, 0.0003, .00002],
#        'RBDL'   : [0.0005, 0.0003, 0.0003, 0.0002, 0.0004],
#        'u2c'   : [0.0003, 0.0002, 0.0004, 0.0004, 0.0005]}


source = ColumnDataSource(data=data)

p1 = figure(x_range=fruits, y_range=(0, 60), plot_height=180, title="6-dof ur5",
           toolbar_location=None, tools="", plot_width = 730)

p1.vbar(x=dodge('fruits', -0.30, range=p1.x_range), top='pybullet', width=0.15, source=source,
       color=palette2[0], legend=False)

p1.vbar(x=dodge('fruits',  -0.10,  range=p1.x_range), top='RBDL', width=0.15, source=source,
       color=palette2[1], legend=False)

p1.vbar(x=dodge('fruits',  0.10, range=p1.x_range), top='u2c', width=0.15, source=source,
       color=palette2[2], legend=False)

p1.vbar(x=dodge('fruits',  0.30, range=p1.x_range), top='KDL', width=0.15, source=source,
       color = palette2[3], legend=False)

labels = LabelSet(x='fruits', level='glyph',
        x_offset=-13.5, y_offset=0, source=source, render_mode='canvas')

p1.x_range.range_padding = 0.1
p1.xgrid.grid_line_color = None
p1.legend.location = "top_left"
p1.legend.orientation = "horizontal"
p1.yaxis.axis_label = 'mean computation time [us]'
p1.axis.minor_tick_line_color = None
#p1.yaxis.axis_label = 'computation time [us]'
#show(p1)

# %%
from bokeh.layouts import column, row

fruits = ['G', 'C', 'ID', 'M', 'FD']
years = ['pybullet', 'RBDL', 'u2c']

data = {'fruits' : fruits,
        'pybullet'   : [pb_snake_g, pb_snake_C, pb_snake_id, pb_snake_M, 0],
        'RBDL'   : [rbdl_snake_g, rbdl_snake_C, rbdl_snake_id, rbdl_snake_M, rbdl_snake_fd],
        'u2c'   : [u2c_snake_g, u2c_snake_C, u2c_snake_id, u2c_snake_M, u2c_snake_fd],
        'KDL'   : [kdl_snake_g, kdl_snake_C, 0, kdl_snake_M, 0]}

#data = {'fruits' : fruits,
#        'pybullet'   : [0.0002, 0.0001, 0.0004, 0.0003, .00002],
#        'RBDL'   : [0.0005, 0.0003, 0.0003, 0.0002, 0.0004],
#        'u2c'   : [0.0003, 0.0002, 0.0004, 0.0004, 0.0005]}


source = ColumnDataSource(data=data)

p2 = figure(x_range=fruits, y_range=(0, 60), plot_height=180, title="16-dof mamba",
           toolbar_location=None, tools="", plot_width=730)

p2.vbar(x=dodge('fruits', -0.30, range=p2.x_range), top='pybullet', width=0.15, source=source,
       color=palette2[0], legend=False)

p2.vbar(x=dodge('fruits',  -0.10,  range=p2.x_range), top='RBDL', width=0.15, source=source,
       color=palette2[1], legend=False)

p2.vbar(x=dodge('fruits',  0.10, range=p2.x_range), top='u2c', width=0.15, source=source,
       color=palette2[2], legend=False)

p2.vbar(x=dodge('fruits',  0.30, range=p2.x_range), top='KDL', width=0.15, source=source,
       color = palette2[3], legend=False)

p2.x_range.range_padding = 0.1
p2.xgrid.grid_line_color = None
p2.legend.location = "top_left"
p2.legend.orientation = "horizontal"
p2.yaxis.axis_label = 'mean computation time [us]'
p2.axis.minor_tick_line_color = None
#p2.yaxis.axis_label = 'computation time [us]'

# %%
fruits = ['G', 'C', 'ID', 'M', 'FD']
years = ['pybullet', 'RBDL', 'u2c']

data = {'fruits' : fruits,
        'pybullet'   : [pb_pendel_g, pb_pendel_C, pb_pendel_id, pb_pendel_M, 0],
        'RBDL'   : [rbdl_pendel_g, rbdl_pendel_C, rbdl_pendel_id, rbdl_pendel_M, rbdl_pendel_fd],
        'u2c'   : [u2c_pendel_g, u2c_pendel_C, u2c_pendel_id, u2c_pendel_M, u2c_pendel_fd],
        'KDL'   : [kdl_pendel_g, kdl_pendel_C, 0, kdl_pendel_M, 0]}

#data = {'fruits' : fruits,
#        'pybullet'   : [0.0002, 0.0001, 0.0004, 0.0003, .00002],
#        'RBDL'   : [0.0005, 0.0003, 0.0003, 0.0002, 0.0004],
#        'u2c'   : [0.0003, 0.0002, 0.0004, 0.0004, 0.0005]}


source = ColumnDataSource(data=data)

p3 = figure(x_range=fruits, y_range=(0, 60), plot_height=180, title="2-dof pendelum",
           toolbar_location=None, tools="", plot_width = 730)

p3.vbar(x=dodge('fruits', -0.30, range=p3.x_range), top='pybullet', width=0.15, source=source,
       color=palette2[0], legend=value("pybullet"))

p3.vbar(x=dodge('fruits',  -0.10,  range=p3.x_range), top='RBDL', width=0.15, source=source,
       color=palette2[1], legend=value("RBDL"))

p3.vbar(x=dodge('fruits',  0.10, range=p3.x_range), top='u2c', width=0.15, source=source,
       color=palette2[2], legend=value("u2c"))

p3.vbar(x=dodge('fruits',  0.30, range=p3.x_range), top='KDL', width=0.15, source=source,
       color = palette2[3], legend=value("KDL"))

p3.x_range.range_padding = 0.1
p3.xgrid.grid_line_color = None
p3.legend.location = "top_left"
p3.legend.orientation = "horizontal"
p3.axis.minor_tick_line_color = None
p3.yaxis.axis_label = 'mean computation time [us]'

# %%
plots = column(p3, p1, p2)
show(plots)

# %%
palette1 = ["#AA8439", "#7B9F35", "#882D61", "#2E4272"]
palette2 = ["#DA9815", "#8ECB14", "#AF116A", "#1C4092"] 
palette3 = ["#FFAA00", "#A0F000", "#D30077", "#0B3FB5"]
