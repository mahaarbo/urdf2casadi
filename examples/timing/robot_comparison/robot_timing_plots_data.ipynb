# %% [markdown]
# # ur5 data

# %%
scale5 = 0.00001*1000000
scale6 = 0.000001*1000000

ur5_g_u2c= 1.54621839523*scale5

ur5_id_u2c= 3.64641666412*scale5

ur5_C_u2c= 2.6023542881*scale5

ur5_M_u2c= 1.66308999062*scale5

ur5_fd_aba_u2c= 3.72484564781*scale5

ur5_fd_crba_u2c= 3.97567033768*scale5

print ur5_g_u2c
# Out:
# 15.4621839523

# %%
ur5_g_pb= 5.05030155182*scale6

ur5_id_pb= 1.03515505791*scale5


ur5_C_pb= 7.7164888382*scale6

ur5_M_pb= 5.62341213226*scale6

# %%
ur5_g_kdl= 1.23634934425*scale5

ur5_C_kdl= 1.55902981758*scale5

ur5_M_kdl= 1.32323980331*scale5

# %%
ur5_g_rbdl= 6.24589920044*scale6

ur5_id_rbdl= 1.18062973022*scale5

ur5_C_rbdl= 9.0437412262*scale6

ur5_M_rbdl= 5.31970262527*scale6

ur5_fd_rbdl= 1.29534482956*scale5

# %%
#new data

 
ur5_g_u2c= 8.16750526428

ur5_id_u2c= 31.4220190048

ur5_C_u2c= 20.5310583115

ur5_g_rbdl= 6.03294372559

ur5_id_rbdl= 11.7515325546

ur5_C_rbdl= 8.43501091003

ur5_g_pb= 5.03146648407

ur5_id_pb= 10.2944374084

ur5_C_pb= 7.60698318481

ur5_g_kdl= 12.3100280762

ur5_C_kdl= 15.5606269836





ur5_g_u2c= 8.16750526428

ur5_id_u2c= 31.9805145264

ur5_C_u2c= 20.9115743637

ur5_M_u2c= 8.8210105896

ur5_g_rbdl= 6.01983070374

ur5_id_rbdl= 11.7899179459

ur5_C_rbdl= 8.41856002808

ur5_M_rbdl= 5.26201725006

ur5_g_pb= 5.00249862671

ur5_id_pb= 10.2338790894

ur5_C_pb= 7.63654708862

ur5_M_pb= 5.51843643188

ur5_g_kdl= 12.2628211975

ur5_C_kdl= 15.8898830414

ur5_M_kdl= 13.2830142975
drbdl= 13.1685733795

fdcrba= 37.5194549561

fdaba= 32.1755409241

# %% [markdown]
# # pendulum data

# %%
pendel_g_u2c= 1.31130218506*scale5

pendel_id_u2c= 3.19480895996*scale5

pendel_C_u2c= 2.09808349609*scale5

pendel_M_u2c= 1.31130218506*scale5

pendel_fd_aba_u2c= 3.00407409668*scale5

pendel_fd_crba_u2c= 3.00407409668*scale5

# %%
pendel_g_pb= 3.09944152832*scale6

pendel_id_pb= 5.00679016113*scale6

pendel_C_pb= 4.05311584473*scale6

pendel_M_pb= 2.86102294922*scale6

# %%
pendel_g_kdl= 5.96046447754*scale6

pendel_C_kdl= 6.91413879395*scale6

pendel_M_kdl= 5.96046447754*scale6

# %%
pendel_g_rbdl= 4.05311584473*scale6

pendel_id_rbdl= 5.00679016113*scale6

pendel_C_rbdl= 5.00679016113*scale6

pendel_M_rbdl= 2.86102294922*scale6

pendel_fd_rbdl= 5.96046447754*scale6

# %%
#new data


pendulum_g_u2c= 6.56688213348

pendulum_id_u2c= 25.8663892746

pendulum_C_u2c= 16.4796113968

pendulum_g_rbdl= 3.0345916748

pendulum_id_rbdl= 4.82845306396

pendulum_C_rbdl= 3.72755527496

pendulum_g_pb= 2.39253044128

pendulum_id_pb= 4.0009021759

pendulum_C_pb= 3.20291519165

pendulum_g_kdl= 4.80544567108

pendulum_C_kdl= 5.99098205566

# %% [markdown]
# # snake data

# %%
snake_g_rbdl= 1.50295972824*scale5

snake_id_rbdl= 3.10234069824*scale5

snake_C_rbdl= 2.31941103935*scale5

snake_M_rbdl= 1.46150946617*scale5

snake_fd_rbdl= 3.3531498909*scale5

# %%
snake_g_kdl= 2.21590399742*scale5

snake_C_kdl= 3.06058645248*scale5

snake_M_kdl= 2.50537037849*scale5

# %%
snake_g_pb= 1.22357487679*scale5
snake_id_pb= 2.58797883987*scale5

snake_C_pb= 1.90866470337*scale5

snake_M_pb= 1.62697076797*scale5

# %%
snake_g_u2c= 2.20066428185*scale5

snake_id_u2c= 5.42255401611*scale5

snake_C_u2c= 3.74470591545*scale5

snake_M_u2c= 2.26727485657*scale5

snake_fd_aba_u2c= 5.45042991638*scale5

snake_fd_crba_u2c= 7.03647017479*scale5

# %%
#new data


snake_g_u2c= 13.6944055557

snake_id_u2c= 48.4790802002

snake_C_u2c= 31.5970182419

snake_g_rbdl= 14.4485235214

snake_id_rbdl= 30.1619768143

snake_C_rbdl= 21.6618776321

snake_g_pb= 11.6760730743

snake_id_pb= 26.3245105743

snake_C_pb= 19.0000534058

snake_g_kdl= 22.5610733032

snake_C_kdl= 31.1254262924

# %% [markdown]
# # Plots
# ## Library comparison plots for different robots:

# %% [markdown]
# ## 3 robots:

# %%
palette1 = ["#AA8439", "#7B9F35", "#882D61", "#2E4272"]
palette2 = ["#DA9815", "#8ECB14", "#AF116A", "#1C4092"] 
palette3 = ["#FFAA00", "#A0F000", "#D30077", "#0B3FB5"]


c1 = ["#802B67", "#AA8039", "#2C4870", "#84A136"]
      
c2 = [ "#2D0320", "#3C2704","#061327", "#2A3803"]  

c3 = [ "#571142", "#735117","#142B4C", "#556D15"]  

c4 = [ "#AA508F", "#E1B56A","#4D6A95", "#B7D564"]  

c5 = [ "#D380BA", "#FFDA9A","#7C98C2", "#DCF594"]

# %%
from bokeh.core.properties import value
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge
from bokeh.models import ColumnDataSource, ranges, LabelSet

output_file("dodged_bars.html")

dynamics = ['G', 'C', 'ID', 'M', 'FD']
libraries = ['pybullet', 'RBDL', 'u2c', 'KDL']

data = {'dynamics' : dynamics,
        'pybullet'   : [ur5_g_pb, ur5_C_pb, ur5_id_pb, ur5_M_pb, 0],
        'RBDL'   : [ur5_g_rbdl, ur5_C_rbdl, ur5_id_rbdl, ur5_M_rbdl, ur5_fd_rbdl],
        'u2c'   : [ur5_g_u2c, ur5_C_u2c, ur5_id_u2c, ur5_M_u2c, ur5_fd_aba_u2c],
        'KDL'   : [ur5_g_kdl, ur5_C_kdl, 0, ur5_M_kdl, 0]}


source = ColumnDataSource(data=data)

ur5_hist = figure(x_range=dynamics, y_range=(0, 50), plot_height=210, title= "6-dof UR5",
           toolbar_location=None, tools="", plot_width = 600)

ur5_hist.vbar(x=dodge('dynamics', -0.30, range=ur5_hist.x_range), top='pybullet', width=0.15, source=source,
       color=c4[1], legend=value("pybullet"))

ur5_hist.vbar(x=dodge('dynamics',  -0.10,  range=ur5_hist.x_range), top='RBDL', width=0.15, source=source,
       color=c4[3], legend=value("RBDL"))

ur5_hist.vbar(x=dodge('dynamics',  0.10, range=ur5_hist.x_range), top='u2c', width=0.15, source=source,
       color=c4[0], legend=value("u2c"))

ur5_hist.vbar(x=dodge('dynamics',  0.30, range=ur5_hist.x_range), top='KDL', width=0.15, source=source,
       color = c4[2], legend=value("KDL"))

labels = LabelSet(x='dynamics', level='glyph',
        x_offset=-13.5, y_offset=0, source=source, render_mode='canvas')

ur5_hist.x_range.range_padding = 0.1
ur5_hist.xgrid.grid_line_color = None
ur5_hist.legend.location = "top_left"
ur5_hist.legend.orientation = "horizontal"
ur5_hist.yaxis.axis_label = 'median evaluation time [us]'
ur5_hist.axis.minor_tick_line_color = None
#ur5_hist.yaxis.axis_label = 'computation time [us]'
#show(ur5_hist)

# %%
from bokeh.core.properties import value
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge
from bokeh.models import ColumnDataSource, ranges, LabelSet

output_file("dodged_bars.html")

dynamics = ['G', 'C', 'ID', 'M', 'FD']
libraries = ['pybullet', 'RBDL', 'u2c', 'KDL']

data = {'dynamics' : dynamics,
        'pybullet'   : [pendel_g_pb, pendel_C_pb, pendel_id_pb, pendel_M_pb, 0],
        'RBDL'   : [pendel_g_rbdl, pendel_C_rbdl, pendel_id_rbdl, pendel_M_rbdl, pendel_fd_rbdl],
        'u2c'   : [pendel_g_u2c, pendel_C_u2c, pendel_id_u2c, pendel_M_u2c, pendel_fd_aba_u2c],
        'KDL'   : [pendel_g_kdl, pendel_C_kdl, 0, pendel_M_kdl, 0]}


source = ColumnDataSource(data=data)

pendel_hist = figure(x_range=dynamics, y_range=(0, 40), plot_height=210, title="2-dof pendulum",
           toolbar_location=None, tools="", plot_width = 600)

pendel_hist.vbar(x=dodge('dynamics', -0.30, range=pendel_hist.x_range), top='pybullet', width=0.15, source=source,
       color=c4[1], legend=value("pybullet"))

pendel_hist.vbar(x=dodge('dynamics',  -0.10,  range=pendel_hist.x_range), top='RBDL', width=0.15, source=source,
       color=c4[3], legend=value("RBDL"))

pendel_hist.vbar(x=dodge('dynamics',  0.10, range=pendel_hist.x_range), top='u2c', width=0.15, source=source,
       color=c4[0], legend=value("u2c"))

pendel_hist.vbar(x=dodge('dynamics',  0.30, range=pendel_hist.x_range), top='KDL', width=0.15, source=source,
       color = c4[2], legend=value("KDL"))

labels = LabelSet(x='dynamics', level='glyph',
        x_offset=-13.5, y_offset=0, source=source, render_mode='canvas')

pendel_hist.x_range.range_padding = 0.1
pendel_hist.xgrid.grid_line_color = None
pendel_hist.legend.location = "top_left"
pendel_hist.legend.orientation = "horizontal"
pendel_hist.yaxis.axis_label = 'median evaluation time [us]'
pendel_hist.axis.minor_tick_line_color = None
#pendel_hist.yaxis.axis_label = 'computation time [us]'
#show(pendel_hist)

# %%
from bokeh.core.properties import value
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge
from bokeh.models import ColumnDataSource, ranges, LabelSet
from bokeh.layouts import column, row


output_file("dodged_bars.html")

dynamics = ['G', 'C', 'ID', 'M', 'FD']
libraries = ['pybullet', 'RBDL', 'u2c', 'KDL']

data = {'dynamics' : dynamics,
        'pybullet'   : [snake_g_pb, snake_C_pb, snake_id_pb, snake_M_pb, 0],
        'RBDL'   : [snake_g_rbdl, snake_C_rbdl, snake_id_rbdl, snake_M_rbdl, snake_fd_rbdl],
        'u2c'   : [snake_g_u2c, snake_C_u2c, snake_id_u2c, snake_M_u2c, snake_fd_aba_u2c],
        'KDL'   : [snake_g_kdl, snake_C_kdl, 0, snake_M_kdl, 0]}


source = ColumnDataSource(data=data)

snake_hist = figure(x_range=dynamics, y_range=(0, 60), plot_height=210, title="16-dof snake",
           toolbar_location=None, tools="", plot_width = 600)

snake_hist.vbar(x=dodge('dynamics', -0.30, range=snake_hist.x_range), top='pybullet', width=0.15, source=source,
       color=c4[1], legend=value("pybullet"))

snake_hist.vbar(x=dodge('dynamics',  -0.10,  range=snake_hist.x_range), top='RBDL', width=0.15, source=source,
       color=c4[3], legend=value("RBDL"))

snake_hist.vbar(x=dodge('dynamics',  0.10, range=snake_hist.x_range), top='u2c', width=0.15, source=source,
       color=c4[0], legend=value("u2c"))

snake_hist.vbar(x=dodge('dynamics',  0.30, range=snake_hist.x_range), top='KDL', width=0.15, source=source,
       color = c4[2], legend=value("KDL"))

labels = LabelSet(x='dynamics', level='glyph',
        x_offset=-13.5, y_offset=0, source=source, render_mode='canvas')

snake_hist.x_range.range_padding = 0.1
snake_hist.xgrid.grid_line_color = None
snake_hist.legend.location = "top_left"
snake_hist.legend.orientation = "horizontal"
snake_hist.yaxis.axis_label = 'median evaluation time [us]'
plots = column(pendel_hist, ur5_hist, snake_hist)
show(plots)

# %% [markdown]
# ## pendel:

# %%
from bokeh.core.properties import value
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge
from bokeh.models import ColumnDataSource, ranges, LabelSet
from bokeh.io import export_png

output_file("dodged_bars.html")

dynamics = ['G', 'C', 'ID', 'M', 'FD']
libraries = ['pybullet', 'RBDL', 'u2c', 'KDL']

data = {'dynamics' : dynamics,
        'pybullet'   : [pendel_g_pb, pendel_C_pb, pendel_id_pb, pendel_M_pb, 0],
        'RBDL'   : [pendel_g_rbdl, pendel_C_rbdl, pendel_id_rbdl, pendel_M_rbdl, pendel_fd_rbdl],
        'u2c'   : [pendel_g_u2c, pendel_C_u2c, pendel_id_u2c, pendel_M_u2c, pendel_fd_aba_u2c],
        'KDL'   : [pendel_g_kdl, pendel_C_kdl, 0, pendel_M_kdl, 0]}


source = ColumnDataSource(data=data)

pendel_hist = figure(x_range=dynamics, y_range=(0, 40), plot_height=210, title= "2-dof pendulum",
           toolbar_location=None, tools="", plot_width = 600)

pendel_hist.vbar(x=dodge('dynamics', -0.30, range=pendel_hist.x_range), top='pybullet', width=0.15, source=source,
       color=c4[1], legend=value("pybullet"))

pendel_hist.vbar(x=dodge('dynamics',  -0.10,  range=pendel_hist.x_range), top='RBDL', width=0.15, source=source,
       color=c4[3], legend=value("RBDL"))

pendel_hist.vbar(x=dodge('dynamics',  0.10, range=pendel_hist.x_range), top='u2c', width=0.15, source=source,
       color=c4[0], legend=value("u2c"))

pendel_hist.vbar(x=dodge('dynamics',  0.30, range=pendel_hist.x_range), top='KDL', width=0.15, source=source,
       color = c4[2], legend=value("KDL"))

labels = LabelSet(x='dynamics', level='glyph',
        x_offset=-13.5, y_offset=0, source=source, render_mode='canvas')

pendel_hist.x_range.range_padding = 0.1
pendel_hist.xgrid.grid_line_color = None
pendel_hist.legend.location = "top_left"
pendel_hist.legend.orientation = "horizontal"
pendel_hist.yaxis.axis_label = 'median evaluation time [us]'
pendel_hist.axis.minor_tick_line_color = None
#pendel_hist.yaxis.axis_label = 'computation time [us]'
show(pendel_hist)

#export_png(pendel_hist, filename="pendel_hist.png")

# %% [markdown]
# ## ur5:

# %%
from bokeh.core.properties import value
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge
from bokeh.models import ColumnDataSource, ranges, LabelSet

output_file("dodged_bars.html")

dynamics = ['G', 'C', 'ID', 'M', 'FD']
libraries = ['pybullet', 'RBDL', 'u2c', 'KDL']

data = {'dynamics' : dynamics,
        'pybullet'   : [ur5_g_pb, ur5_C_pb, ur5_id_pb, ur5_M_pb, 0],
        'RBDL'   : [ur5_g_rbdl, ur5_C_rbdl, ur5_id_rbdl, ur5_M_rbdl, ur5_fd_rbdl],
        'u2c'   : [ur5_g_u2c, ur5_C_u2c, ur5_id_u2c, ur5_M_u2c, ur5_fd_aba_u2c],
        'KDL'   : [ur5_g_kdl, ur5_C_kdl, 0, ur5_M_kdl, 0]}


source = ColumnDataSource(data=data)

ur5_hist = figure(x_range=dynamics, y_range=(0, 50), plot_height=210, title= "6-dof UR5",
           toolbar_location=None, tools="", plot_width = 600)

ur5_hist.vbar(x=dodge('dynamics', -0.30, range=ur5_hist.x_range), top='pybullet', width=0.15, source=source,
       color=c4[1], legend=value("pybullet"))

ur5_hist.vbar(x=dodge('dynamics',  -0.10,  range=ur5_hist.x_range), top='RBDL', width=0.15, source=source,
       color=c4[3], legend=value("RBDL"))

ur5_hist.vbar(x=dodge('dynamics',  0.10, range=ur5_hist.x_range), top='u2c', width=0.15, source=source,
       color=c4[0], legend=value("u2c"))

ur5_hist.vbar(x=dodge('dynamics',  0.30, range=ur5_hist.x_range), top='KDL', width=0.15, source=source,
       color = c4[2], legend=value("KDL"))

labels = LabelSet(x='dynamics', level='glyph',
        x_offset=-13.5, y_offset=0, source=source, render_mode='canvas')

ur5_hist.x_range.range_padding = 0.1
ur5_hist.xgrid.grid_line_color = None
ur5_hist.legend.location = "top_left"
ur5_hist.legend.orientation = "horizontal"
ur5_hist.yaxis.axis_label = 'median evaluation time [us]'
ur5_hist.axis.minor_tick_line_color = None
#ur5_hist.yaxis.axis_label = 'computation time [us]'
show(ur5_hist)

# %% [markdown]
# ## snake:

# %%
from bokeh.core.properties import value
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge
from bokeh.models import ColumnDataSource, ranges, LabelSet

output_file("dodged_bars.html")

dynamics = ['G', 'C', 'ID', 'M', 'FD']
libraries = ['pybullet', 'RBDL', 'u2c', 'KDL']

data = {'dynamics' : dynamics,
        'pybullet'   : [snake_g_pb, snake_C_pb, snake_id_pb, snake_M_pb, 0],
        'RBDL'   : [snake_g_rbdl, snake_C_rbdl, snake_id_rbdl, snake_M_rbdl, snake_fd_rbdl],
        'u2c'   : [snake_g_u2c, snake_C_u2c, snake_id_u2c, snake_M_u2c, snake_fd_aba_u2c],
        'KDL'   : [snake_g_kdl, snake_C_kdl, 0, snake_M_kdl, 0]}


source = ColumnDataSource(data=data)

snake_hist = figure(x_range=dynamics, y_range=(0, 60), plot_height=210, title= "16-dof snake",
           toolbar_location=None, tools="", plot_width = 600)

snake_hist.vbar(x=dodge('dynamics', -0.30, range=snake_hist.x_range), top='pybullet', width=0.15, source=source,
       color=c4[1], legend=value("pybullet"))

snake_hist.vbar(x=dodge('dynamics',  -0.10,  range=snake_hist.x_range), top='RBDL', width=0.15, source=source,
       color=c4[3], legend=value("RBDL"))

snake_hist.vbar(x=dodge('dynamics',  0.10, range=snake_hist.x_range), top='u2c', width=0.15, source=source,
       color=c4[0], legend=value("u2c"))

snake_hist.vbar(x=dodge('dynamics',  0.30, range=snake_hist.x_range), top='KDL', width=0.15, source=source,
       color = c4[2], legend=value("KDL"))

labels = LabelSet(x='dynamics', level='glyph',
        x_offset=-13.5, y_offset=0, source=source, render_mode='canvas')

snake_hist.x_range.range_padding = 0.1
snake_hist.xgrid.grid_line_color = None
snake_hist.legend.location = "top_left"
snake_hist.legend.orientation = "horizontal"
snake_hist.yaxis.axis_label = 'median evaluation time [us]'
snake_hist.axis.minor_tick_line_color = None
#snake_hist.yaxis.axis_label = 'computation time [us]'
show(snake_hist)

# %% [markdown]
# # Library plots:
# ## u2c:

# %%
output_file("dodged_bars.html")

dynamics = ['pendulum', 'ur5', 'mamba']
libraries = ['G', 'C', 'ID']

data = {'dynamics' : dynamics,
        'G'   : [pendel_g_u2c, ur5_g_u2c, snake_g_u2c],
        'C'   : [pendel_C_u2c, ur5_C_u2c, snake_C_u2c],
        'ID'   : [pendel_id_u2c, ur5_id_u2c, snake_id_u2c]}
        #'KDL'   : [pendel_g_kdl, pendel_C_kdl, 0, pendel_M_kdl, 0]}


source = ColumnDataSource(data=data)

u2c_rnea = figure(x_range=dynamics, y_range=(0, 60), plot_height=180, title= "rnea dynamics",
           toolbar_location=None, tools="")#, plot_width = 730)

u2c_rnea.vbar(x=dodge('dynamics', -0.30, range=u2c_rnea.x_range), top='G', width=0.15, source=source,
       color=palette2[0], legend=value("G"))

u2c_rnea.vbar(x=dodge('dynamics',  -0.10,  range=u2c_rnea.x_range), top='C', width=0.15, source=source,
       color=palette2[1], legend=value("C"))

u2c_rnea.vbar(x=dodge('dynamics',  0.10, range=u2c_rnea.x_range), top='ID', width=0.15, source=source,
       color=palette2[2], legend=value("ID"))

#u2c_rnea.vbar(x=dodge('dynamics',  0.30, range=u2c_rnea.x_range), top='KDL', width=0.15, source=source,
#       color = palette2[3], legend=value("KDL"))

#labels = LabelSet(x='dynamics', level='glyph',
#        x_offset=-13.5, y_offset=0, source=source, render_mode='canvas')

u2c_rnea.x_range.range_padding = 0.1
u2c_rnea.xgrid.grid_line_color = None
u2c_rnea.legend.location = "top_left"
u2c_rnea.legend.orientation = "horizontal"
u2c_rnea.yaxis.axis_label = 'median evaluation time [us]'
u2c_rnea.axis.minor_tick_line_color = None
#u2c_rnea.yaxis.axis_label = 'computation time [us]'
show(u2c_rnea)

# %%
libraries = ['penulum', 'ur5', 'mamba']
dynamics = ['G', 'C', 'ID']

data = {'dynamics' : dynamics,
        'pendulum'   : [pendel_g_u2c, pendel_C_u2c, pendel_id_u2c],
        'ur5'   : [ur5_g_u2c, ur5_C_u2c, ur5_id_u2c],
        'mamba'   : [snake_g_u2c, snake_C_u2c, snake_id_u2c]}
        #'KDL'   : [pendel_g_kdl, pendel_C_kdl, 0, pendel_M_kdl, 0]}


source = ColumnDataSource(data=data)

u2c_rnea = figure(x_range=dynamics, y_range=(0, 60), plot_height=180, title= "rnea dynamics",
           toolbar_location=None, tools="")#, plot_width = 730)

u2c_rnea.vbar(x=dodge('dynamics', -0.30, range=u2c_rnea.x_range), top='pendulum', width=0.15, source=source,
       color=palette2[0], legend=value("pendulum"))

u2c_rnea.vbar(x=dodge('dynamics',  -0.10,  range=u2c_rnea.x_range), top='ur5', width=0.15, source=source,
       color=palette2[1], legend=value("ur5"))

u2c_rnea.vbar(x=dodge('dynamics',  0.10, range=u2c_rnea.x_range), top='mamba', width=0.15, source=source,
       color=palette2[2], legend=value("mamba"))

#u2c_rnea.vbar(x=dodge('dynamics',  0.30, range=u2c_rnea.x_range), top='KDL', width=0.15, source=source,
#       color = palette2[3], legend=value("KDL"))

#labels = LabelSet(x='dynamics', level='glyph',
#        x_offset=-13.5, y_offset=0, source=source, render_mode='canvas')

u2c_rnea.x_range.range_padding = 0.1
u2c_rnea.xgrid.grid_line_color = None
u2c_rnea.legend.location = "top_left"
u2c_rnea.legend.orientation = "horizontal"
u2c_rnea.yaxis.axis_label = 'median evaluation time [us]'
u2c_rnea.axis.minor_tick_line_color = None
#u2c_rnea.yaxis.axis_label = 'computation time [us]'
show(u2c_rnea)

# %%
output_file("dodged_bars.html")

dynamics = ['pendulum', 'ur5', 'mamba']
libraries = ['G', 'C', 'ID']

data = {'dynamics' : dynamics,
        'G'   : [pendel_g_rbdl, ur5_g_rbdl, snake_g_rbdl],
        'C'   : [pendel_C_rbdl, ur5_C_rbdl, snake_C_rbdl],
        'ID'   : [pendel_id_rbdl, ur5_id_rbdl, snake_id_rbdl]}
        #'KDL'   : [pendel_g_kdl, pendel_C_kdl, 0, pendel_M_kdl, 0]}


source = ColumnDataSource(data=data)

rbdl_rnea = figure(x_range=dynamics, y_range=(0, 60), plot_height=180, title= "rnea dynamics",
           toolbar_location=None, tools="")#, plot_width = 730)

rbdl_rnea.vbar(x=dodge('dynamics', -0.30, range=rbdl_rnea.x_range), top='G', width=0.15, source=source,
       color=palette2[0], legend=value("G"))

rbdl_rnea.vbar(x=dodge('dynamics',  -0.10,  range=rbdl_rnea.x_range), top='C', width=0.15, source=source,
       color=palette2[1], legend=value("C"))

rbdl_rnea.vbar(x=dodge('dynamics',  0.10, range=rbdl_rnea.x_range), top='ID', width=0.15, source=source,
       color=palette2[2], legend=value("ID"))

#rbdl_rnea.vbar(x=dodge('dynamics',  0.30, range=rbdl_rnea.x_range), top='KDL', width=0.15, source=source,
#       color = palette2[3], legend=value("KDL"))

#labels = LabelSet(x='dynamics', level='glyph',
#        x_offset=-13.5, y_offset=0, source=source, render_mode='canvas')

rbdl_rnea.x_range.range_padding = 0.1
rbdl_rnea.xgrid.grid_line_color = None
rbdl_rnea.legend.location = "top_left"
rbdl_rnea.legend.orientation = "horizontal"
rbdl_rnea.yaxis.axis_label = 'median evaluation time [us]'
rbdl_rnea.axis.minor_tick_line_color = None
#rbdl_rnea.yaxis.axis_label = 'computation time [us]'
#show(rbdl_rnea)


libraries = ['penulum', 'ur5', 'mamba']
dynamics = ['G', 'C', 'ID']

data = {'dynamics' : dynamics,
        'pendulum'   : [pendel_g_rbdl, pendel_C_rbdl, pendel_id_rbdl],
        'ur5'   : [ur5_g_rbdl, ur5_C_rbdl, ur5_id_rbdl],
        'mamba'   : [snake_g_rbdl, snake_C_rbdl, snake_id_rbdl]}
        #'KDL'   : [pendel_g_kdl, pendel_C_kdl, 0, pendel_M_kdl, 0]}


source = ColumnDataSource(data=data)

rbdl_rnea2 = figure(x_range=dynamics, y_range=(0, 60), plot_height=180, title= "rnea dynamics",
           toolbar_location=None, tools="")#, plot_width = 730)

rbdl_rnea2.vbar(x=dodge('dynamics', -0.30, range=rbdl_rnea.x_range), top='pendulum', width=0.15, source=source,
       color=palette2[0], legend=value("pendulum"))

rbdl_rnea2.vbar(x=dodge('dynamics',  -0.10,  range=rbdl_rnea.x_range), top='ur5', width=0.15, source=source,
       color=palette2[1], legend=value("ur5"))

rbdl_rnea2.vbar(x=dodge('dynamics',  0.10, range=rbdl_rnea.x_range), top='mamba', width=0.15, source=source,
       color=palette2[2], legend=value("mamba"))

#rbdl_rnea.vbar(x=dodge('dynamics',  0.30, range=rbdl_rnea.x_range), top='KDL', width=0.15, source=source,
#       color = palette2[3], legend=value("KDL"))

#labels = LabelSet(x='dynamics', level='glyph',
#        x_offset=-13.5, y_offset=0, source=source, render_mode='canvas')

rbdl_rnea2.x_range.range_padding = 0.1
rbdl_rnea2.xgrid.grid_line_color = None
rbdl_rnea2.legend.location = "top_left"
rbdl_rnea2.legend.orientation = "horizontal"
rbdl_rnea2.yaxis.axis_label = 'median evaluation time [us]'
rbdl_rnea2.axis.minor_tick_line_color = None
#rbdl_rnea.yaxis.axis_label = 'computation time [us]'
show(rbdl_rnea)

#plots = column(rbdl_rnea, rbdl_rnea2)
#show(plots)

# %%
output_file("dodged_barss.html")

libraries = ['penulum', 'ur5', 'mamba']
dynamics = ['G', 'C', 'ID']

data = {'dynamics' : dynamics,
        'pendulum'   : [pendel_g_rbdl, pendel_C_rbdl, pendel_id_rbdl],
        'ur5'   : [ur5_g_rbdl, ur5_C_rbdl, ur5_id_rbdl],
        'mamba'   : [snake_g_rbdl, snake_C_rbdl, snake_id_rbdl]}
        #'KDL'   : [pendel_g_kdl, pendel_C_kdl, 0, pendel_M_kdl, 0]}


source = ColumnDataSource(data=data)

rbdl_rnea2 = figure(x_range=dynamics, y_range=(0, 60), plot_height=180, title= "rnea dynamics",
           toolbar_location=None, tools="")#, plot_width = 730)

rbdl_rnea2.vbar(x=dodge('dynamics', -0.30, range=rbdl_rnea.x_range), top='pendulum', width=0.15, source=source,
       color=palette2[0], legend=value("pendulum"))

rbdl_rnea2.vbar(x=dodge('dynamics',  -0.10,  range=rbdl_rnea.x_range), top='ur5', width=0.15, source=source,
       color=palette2[1], legend=value("ur5"))

rbdl_rnea2.vbar(x=dodge('dynamics',  0.10, range=rbdl_rnea.x_range), top='mamba', width=0.15, source=source,
       color=palette2[2], legend=value("mamba"))

#rbdl_rnea.vbar(x=dodge('dynamics',  0.30, range=rbdl_rnea.x_range), top='KDL', width=0.15, source=source,
#       color = palette2[3], legend=value("KDL"))

#labels = LabelSet(x='dynamics', level='glyph',
#        x_offset=-13.5, y_offset=0, source=source, render_mode='canvas')

rbdl_rnea2.x_range.range_padding = 0.1
rbdl_rnea2.xgrid.grid_line_color = None
rbdl_rnea2.legend.location = "top_left"
rbdl_rnea2.legend.orientation = "horizontal"
rbdl_rnea2.yaxis.axis_label = 'median evaluation time [us]'
rbdl_rnea2.axis.minor_tick_line_color = None
#rbdl_rnea.yaxis.axis_label = 'computation time [us]'
#show(rbdl_rnea)

#plots = column(rbdl_rnea, rbdl_rnea2)
show(rbdl_rnea2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-66-f321679ca4f6> in <module>()
#      41
#      42 #plots = column(rbdl_rnea, rbdl_rnea2)
# ---> 43 show(rbdl_rnea2)
#
# /home/lillmaria/.local/lib/python2.7/site-packages/bokeh/io/showing.pyc in show(obj, browser, new, notebook_handle, notebook_url, **kw)
#     143         return run_notebook_hook(state.notebook_type, 'app', obj, state, notebook_url, **kw)
#     144
# --> 145     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     146
#     147 #-----------------------------------------------------------------------------
#
# /home/lillmaria/.local/lib/python2.7/site-packages/bokeh/io/showing.pyc in _show_with_state(obj, state, browser, new, notebook_handle)
#     181
#     182     if state.file or not shown:
# --> 183         _show_file_with_state(obj, state, new, controller)
# ...
